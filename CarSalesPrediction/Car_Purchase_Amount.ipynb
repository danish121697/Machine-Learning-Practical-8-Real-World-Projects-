# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
car_df = pd.read_csv('Car_Purchasing_Data.csv', encoding='ISO-8859-1')

# %%
car_df
# Out:
#        Customer Name                                    Customer e-mail  \
# 0      Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1      Harlan Barnes                                eu.dolor@diam.co.uk
# 2    Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3    Jade Cunningham                            malesuada@dignissim.com
# 4       Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
# ..               ...                                                ...
# 495           Walter                                ligula@Cumsociis.ca
# 496            Vanna                 Cum.sociis.natoque@Sedmolestie.edu
# 497            Pearl                      penatibus.et@massanonante.com
# 498             Nell                  Quisque.varius@arcuVivamussit.net
# 499            Marla                          Camaron.marla@hotmail.com
#
#           Country  Gender        Age  Annual Salary  Credit Card Debt  \
# ...

# %%
car_df.head()
# Out:
#      Customer Name                                    Customer e-mail  \
# 0    Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1    Harlan Barnes                                eu.dolor@diam.co.uk
# 2  Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3  Jade Cunningham                            malesuada@dignissim.com
# 4     Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
#
#         Country  Gender        Age  Annual Salary  Credit Card Debt  \
# 0      Bulgaria       0  41.851720    62812.09301      11609.380910
# 1        Belize       0  40.870623    66646.89292       9572.957136
# 2       Algeria       1  43.152897    53798.55112      11160.355060
# 3  Cook Islands       1  58.271369    79370.03798      14426.164850
# 4        Brazil       1  57.313749    59729.15130       5358.712177
#
#      Net Worth  Car Purchase Amount
# 0  238961.2505          35321.45877
# 1  530973.9078          45115.52566
# ...

# %%
X = car_df.drop(['Customer Name','Customer e-mail', 'Country','Car Purchase Amount'],axis = 1)

# %%
X
# Out:
#      Gender        Age  Annual Salary  Credit Card Debt    Net Worth
# 0         0  41.851720    62812.09301      11609.380910  238961.2505
# 1         0  40.870623    66646.89292       9572.957136  530973.9078
# 2         1  43.152897    53798.55112      11160.355060  638467.1773
# 3         1  58.271369    79370.03798      14426.164850  548599.0524
# 4         1  57.313749    59729.15130       5358.712177  560304.0671
# ..      ...        ...            ...               ...          ...
# 495       0  41.462515    71942.40291       6995.902524  541670.1016
# 496       1  37.642000    56039.49793      12301.456790  360419.0988
# 497       1  53.943497    68888.77805      10611.606860  764531.3203
# 498       1  59.160509    49811.99062      14013.034510  337826.6382
# 499       1  46.731152    61370.67766       9391.341628  462946.4924
#
# [500 rows x 5 columns]

# %%
y = car_df['Car Purchase Amount']

# %%
y.shape
# Out:
# (500,)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler_x = MinMaxScaler()
X_scaled = scaler_x.fit_transform(X)

# %%
scaler_x.data_max_
# Out:
# array([1.e+00, 7.e+01, 1.e+05, 2.e+04, 1.e+06])

# %%
scaler_x.data_min_
# Out:
# array([    0.,    20., 20000.,   100., 20000.])

# %%
print(X_scaled)
# Out:
# [[0.         0.4370344  0.53515116 0.57836085 0.22342985]
#  [0.         0.41741247 0.58308616 0.476028   0.52140195]
#  [1.         0.46305795 0.42248189 0.55579674 0.63108896]
#  ...
#  [1.         0.67886994 0.61110973 0.52822145 0.75972584]
#  [1.         0.78321017 0.37264988 0.69914746 0.3243129 ]
#  [1.         0.53462305 0.51713347 0.46690159 0.45198622]]

# %%
X_scaled.shape
# Out:
# (500, 5)

# %%
y.shape
# Out:
# (500,)

# %%
y = y.values.reshape(-1,1)

# %%
y.shape
# Out:
# (500, 1)

# %%
scaler_y = MinMaxScaler()
y_scaled = scaler_y.fit_transform(y)

# %%
y_scaled
# Out:
# array([[0.37072477],
#        [0.50866938],
#        [0.47782689],
#        [0.82285018],
#        [0.66078116],
#        [0.67059152],
#        [0.28064374],
#        [0.54133778],
#        [0.54948752],
#        [0.4111198 ],
#        [0.70486638],
#        [0.46885649],
#        [0.27746526],
#        [0.56702642],
#        [0.57056385],
#        [0.61996151],
#        [0.46217916],
#        [0.49157341],
#        [0.50188722],
#        [0.64545808],
#        [0.59339372],
#        [0.48453965],
#        [0.53860366],
#        [0.53007738],
#        [0.50814651],
#        [0.49841668],
#        [0.3966416 ],
#        [0.56467566],
#        [0.6950749 ],
#        [0.49287831],
#        [0.12090943],
#        [0.50211776],
#        [0.80794216],
#        [0.62661214],
#        [0.43394857],
#        [0.60017103],
#        [0.42223485],
#        [0.01538345],
#        [0.37927499],
#        [0.64539707],
#        [0.51838974],
#        [0.45869677],
#        [0.26804521],
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size = 0.25)

# %%
scaler_x.data_max_
# Out:
# array([1.e+00, 7.e+01, 1.e+05, 2.e+04, 1.e+06])

# %%
X_train.shape
# Out:
# (375, 5)

# %%
X_scaled.shape
# Out:
# (500, 5)

# %%
import tensorflow.keras
from keras.models import Sequential
from keras.layers import Dense
from sklearn.preprocessing import MinMaxScaler

model = Sequential()

#neurons in the hidden layer,5 input dimension
model.add(Dense(25, input_dim=5, activation='relu'))
model.add(Dense(25, activation='relu'))
#Prediction of only one value
#linear function to give clear output
model.add(Dense(1, activation='linear'))
model.summary()

#Parameters 
#= 150 (5 inputs * 25 weights, + and bias for each input)
#= 625 (5 * 125 + 25)
# = (1*25 + 1)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_1 (Dense)              (None, 25)                150
# _________________________________________________________________
# dense_2 (Dense)              (None, 25)                650
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 26
# ...
# Total params: 826
# Trainable params: 826
# Non-trainable params: 0
# _________________________________________________________________
# Using TensorFlow backend.

# %%
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
epochs_hist = model.fit(X_train, y_train, epochs=20, batch_size=25,  verbose=1, validation_split=0.2)
# Out:
# Train on 300 samples, validate on 75 samples
# Epoch 1/20
# 300/300 [==============================] - 0s 674us/step - loss: 0.0753 - val_loss: 0.0169
# Epoch 2/20
# 300/300 [==============================] - 0s 77us/step - loss: 0.0185 - val_loss: 0.0147
# Epoch 3/20
# 300/300 [==============================] - 0s 56us/step - loss: 0.0132 - val_loss: 0.0069
# Epoch 4/20
# 300/300 [==============================] - 0s 70us/step - loss: 0.0088 - val_loss: 0.0062
# Epoch 5/20
# 300/300 [==============================] - 0s 66us/step - loss: 0.0073 - val_loss: 0.0048
# Epoch 6/20
# 300/300 [==============================] - 0s 68us/step - loss: 0.0065 - val_loss: 0.0045
# Epoch 7/20
# 300/300 [==============================] - 0s 58us/step - loss: 0.0058 - val_loss: 0.0041
# Epoch 8/20
# 300/300 [==============================] - 0s 62us/step - loss: 0.0052 - val_loss: 0.0037
# Epoch 9/20
# 300/300 [==============================] - 0s 60us/step - loss: 0.0048 - val_loss: 0.0035
# ...

# %%
print(epochs_hist.history.keys())
# Out:
# dict_keys(['val_loss', 'loss'])

# %%
plt.plot(epochs_hist.history['loss'])
plt.plot(epochs_hist.history['val_loss'])
plt.title('Model Loss Progression During Training/Validation')
plt.ylabel('Training and Validation Losses')
plt.xlabel('Epoch Number')
plt.legend(['Training Loss', 'Validation Loss'])

# %%
#Gender, Age, Annual Salary, Credit Card Debt, Net Worth
X_test = np.array([[1,50,50000,10000,600000]])
y_predict = model.predict(X_test)
print('Expected Purchase Amount=', y_predict)
# Out:
# Expected Purchase Amount= [[149570.38]]
